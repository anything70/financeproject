# %%
import matplotlib.pyplot as plt
import seaborn
import yfinance as yf
import pandas as pd
import numpy as np
import sklearn
import time

# %%
#yfinance data

ticker = yf.Ticker("AAPL")

try:
    hist = ticker.history(start = "2024-01-01", end = "2024-02-01")
except:
    print("error in gettin the yahoo data")

print(hist.head(5))
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-01-02 00:00:00-05:00  185.789422  187.070052  182.553128  184.290405
# 2024-01-03 00:00:00-05:00  182.880757  184.528693  182.096492  182.910538
# 2024-01-04 00:00:00-05:00  180.825785  181.758954  179.565029  180.587540
# 2024-01-05 00:00:00-05:00  180.666948  181.431339  178.860172  179.862823
# 2024-01-08 00:00:00-05:00  180.766224  184.250716  180.180517  184.210999
#
#                              Volume  Dividends  Stock Splits
# Date
# 2024-01-02 00:00:00-05:00  82488700        0.0           0.0
# 2024-01-03 00:00:00-05:00  58414500        0.0           0.0
# 2024-01-04 00:00:00-05:00  71983600        0.0           0.0
# 2024-01-05 00:00:00-05:00  62303300        0.0           0.0
# 2024-01-08 00:00:00-05:00  59144500        0.0           0.0
