# %%
import matplotlib.pyplot as plt
import seaborn
import yfinance as yf
import pandas as pd
import numpy as np
import sklearn
import time

# %%
#yfinance data

ticker = yf.Ticker("AAPL")

try:
    hist = ticker.history(start = "2024-01-01", end = "2024-12-31")
except:
    print("error in gettin the yahoo data")

print(hist.head(5))
type(hist)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-01-02 00:00:00-05:00  185.789422  187.070052  182.553128  184.290405
# 2024-01-03 00:00:00-05:00  182.880742  184.528677  182.096477  182.910522
# 2024-01-04 00:00:00-05:00  180.825800  181.758969  179.565044  180.587555
# 2024-01-05 00:00:00-05:00  180.666963  181.431354  178.860187  179.862839
# 2024-01-08 00:00:00-05:00  180.766209  184.250701  180.180502  184.210983
#
#                              Volume  Dividends  Stock Splits
# Date
# 2024-01-02 00:00:00-05:00  82488700        0.0           0.0
# 2024-01-03 00:00:00-05:00  58414500        0.0           0.0
# 2024-01-04 00:00:00-05:00  71983600        0.0           0.0
# 2024-01-05 00:00:00-05:00  62303300        0.0           0.0
# 2024-01-08 00:00:00-05:00  59144500        0.0           0.0
# pandas.core.frame.DataFrame
